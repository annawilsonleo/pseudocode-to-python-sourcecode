# %% [markdown]
# <a href="https://colab.research.google.com/github/annawilson123/pseudocode-to-python-sourcecode/blob/main/dataset_creation_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q -U google-generativeai

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
# Used to securely store your API key
from google.colab import userdata

# %%
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
import pandas as pd

# %%
df = pd.read_csv("drive/MyDrive/dataset.csv")

# %%
df = df.drop(columns=['instruction', 'input', 'prompt'])

# %%
df.head()
# Out:
#                                               output
# 0  # Python code\ndef sum_sequence(sequence):\n  ...
# 1  import requests\nimport re\n\ndef crawl_websit...
# 2                 [x*x for x in [1, 2, 3, 5, 8, 13]]
# 3  def remove_duplicates(string): \n    result = ...
# 4  def generate_random_divisible_number():\n    i...

# %%
df.shape
# Out:
# (18612, 1)

# %%
df = df.iloc[4858:4958]

# %%
df.shape
# Out:
# (100, 1)

# %%
df.head()
# Out:
#                                                  output
# 4858  import socket\nimport os\n\nfrom cryptography....
# 4859  import requests\nfrom bs4 import BeautifulSoup...
# 4860  # Defining a function to keep track of the tot...
# 4861  # -*- coding: utf-8 -*-\n# This file is part o...
# 4862  class Library:\n  def __init__(self, name, boo...

# %%
algo = []

# %%
for i in df.index:
  j = str(df['output'][i])
  response = model.generate_content("Write the algorithm for the given Python code:"+j);
  algo.append([i, response.text])
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 636.03ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 634.98ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 662.56ms

# %%
algo
# Out:
# [[4858,
# ...

# %%
algorithm = []

# %%
for [i, j] in algo:
  algorithm.append(str(j))

# %%
algorithm
# Out:
# ["1. Import necessary modules:\n   - socket: For creating a network socket to establish a connection.\n   - os: For file and directory operations.\n   - cryptography.fernet: For encryption and decryption using Fernet.\n\n2. Generate an encryption key:\n   - Use Fernet to generate a unique encryption key. This key will be used to securely encrypt and decrypt messages sent over the network.\n\n3. Create a socket:\n   - Create a new socket using the socket.socket() function with the socket.AF_INET (IPv4) address family and socket.SOCK_STREAM (TCP) socket type.\n\n4. Bind the socket to an address:\n   - Bind the socket to a specific IP address ('127.0.0.1' is used here, which represents the loopback address, meaning the server will listen for connections on the local host) and a port (8080).\n\n5. Listen for incoming connections:\n   - Call the listen() method on the socket to put it in a listening state, waiting for incoming client connections.\n\n6. Accept incoming connections:\n   - U
# ...

# %%
df.insert(0, "Algorithm", algorithm, True)

# %%
df.head()
# Out:
#                                               Algorithm  \
# 4858  1. Import necessary modules:\n   - socket: For...
# 4859  **Algorithm:** \n\n1. **Import necessary libra...
# 4860  Algorithm:\n\n1. Define a function called coun...
# 4861  1. **Import necessary modules and classes.**\n...
# 4862  1. **Initialize the Library Class:**\n   - Def...
#
#                                                  output
# 4858  import socket\nimport os\n\nfrom cryptography....
# 4859  import requests\nfrom bs4 import BeautifulSoup...
# 4860  # Defining a function to keep track of the tot...
# 4861  # -*- coding: utf-8 -*-\n# This file is part o...
# 4862  class Library:\n  def __init__(self, name, boo...

# %%
df.to_csv("data86.csv", sep=',')

# %%
from google.colab import files

# %%
files.download("data86.csv")
